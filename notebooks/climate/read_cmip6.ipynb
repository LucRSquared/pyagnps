# %%
import xarray as xr

# %%
# url = "http://esgf-data1.llnl.gov/thredds/dodsC/css03_data/CMIP6/ScenarioMIP/CNRM-CERFACS/CNRM-CM6-1-HR/ssp585/r1i1p1f2/Amon/pr/gr/v20191202/pr_Amon_CNRM-CM6-1-HR_ssp585_r1i1p1f2_gr_201501-210012.nc"
url = "http://esgf-data1.llnl.gov/thredds/dodsC/css03_data/CMIP6/ScenarioMIP/CNRM-CERFACS/CNRM-CM6-1-HR/ssp585/r1i1p1f2/day/pr/gr/v20191202/pr_day_CNRM-CM6-1-HR_ssp585_r1i1p1f2_gr_20900101-21001231.nc" # daily

# %%
ds = xr.open_dataset(url)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (lat: 360, lon: 720, time: 4017, axis_nbounds: 2)
# Coordinates:
#   * lat          (lat) float64 -89.62 -89.12 -88.62 -88.13 ... 88.62 89.12 89.62
#   * lon          (lon) float64 0.0 0.5 1.0 1.5 2.0 ... 358.0 358.5 359.0 359.5
#   * time         (time) datetime64[ns] 2090-01-01T12:00:00 ... 2100-12-31T12:...
# Dimensions without coordinates: axis_nbounds
# Data variables:
#     time_bounds  (time, axis_nbounds) datetime64[ns] ...
#     pr           (time, lat, lon) float32 ...
# Attributes: (12/53)
#     Conventions:                     CF-1.7 CMIP-6.2
#     creation_date:                   2019-10-26T07:17:02Z
#     description:                     Future scenario with high radiative forc...
#     title:                           CNRM-CM6-1-HR model output prepared for ...
#     activity_id:                     ScenarioMIP
#     contact:                         contact.cmip@meteo.fr
#     ...                              ...
# ...

# %%
ds['pr'].sel(lat=89.0, lon=-34.0, method='nearest').plot()

# %%
ds['pr'].sel(time="2092-11-18", method="nearest").plot()

# %%
urls = [
    "http://esgf-data1.llnl.gov/thredds/dodsC/css03_data/CMIP6/ScenarioMIP/CNRM-CERFACS/CNRM-CM6-1-HR/ssp585/r1i1p1f2/day/tas/gr/v20191202/tas_day_CNRM-CM6-1-HR_ssp585_r1i1p1f2_gr_20150101-20641231.nc",
    "http://esgf-data1.llnl.gov/thredds/dodsC/css03_data/CMIP6/ScenarioMIP/CNRM-CERFACS/CNRM-CM6-1-HR/ssp585/r1i1p1f2/day/tas/gr/v20191202/tas_day_CNRM-CM6-1-HR_ssp585_r1i1p1f2_gr_20650101-21001231.nc"
]

# %%
ds1
# Out:
# <xarray.Dataset>
# Dimensions:      (lat: 360, lon: 720, time: 13148, axis_nbounds: 2)
# Coordinates:
#   * lat          (lat) float64 -89.62 -89.12 -88.62 -88.13 ... 88.62 89.12 89.62
#   * lon          (lon) float64 0.0 0.5 1.0 1.5 2.0 ... 358.0 358.5 359.0 359.5
#     height       float64 ...
#   * time         (time) datetime64[ns] 2065-01-01T12:00:00 ... 2100-12-31T12:...
# Dimensions without coordinates: axis_nbounds
# Data variables:
#     time_bounds  (time, axis_nbounds) datetime64[ns] ...
#     tas          (time, lat, lon) float32 ...
# Attributes: (12/53)
#     Conventions:                     CF-1.7 CMIP-6.2
#     creation_date:                   2019-10-16T18:56:28Z
#     description:                     Future scenario with high radiative forc...
#     title:                           CNRM-CM6-1-HR model output prepared for ...
#     activity_id:                     ScenarioMIP
#     contact:                         contact.cmip@meteo.fr
# ...

# %%
ds0 = xr.open_dataset(urls[0])
ds1 = xr.open_dataset(urls[1])

# ds = xr.open_mfdataset(urls, concat_dim='time', combine="nested")

# %%
ds0
# Out:
# <xarray.Dataset>
# Dimensions:      (lat: 360, lon: 720, time: 18263, axis_nbounds: 2)
# Coordinates:
#   * lat          (lat) float64 -89.62 -89.12 -88.62 -88.13 ... 88.62 89.12 89.62
#   * lon          (lon) float64 0.0 0.5 1.0 1.5 2.0 ... 358.0 358.5 359.0 359.5
#     height       float64 2.0
#   * time         (time) datetime64[ns] 2015-01-01T12:00:00 ... 2064-12-31T12:...
# Dimensions without coordinates: axis_nbounds
# Data variables:
#     time_bounds  (time, axis_nbounds) datetime64[ns] 2015-01-01 ... 2065-01-01
#     tas          (time, lat, lon) float32 ...
# Attributes: (12/53)
#     Conventions:                     CF-1.7 CMIP-6.2
#     creation_date:                   2019-09-13T14:50:52Z
#     description:                     Future scenario with high radiative forc...
#     title:                           CNRM-CM6-1-HR model output prepared for ...
#     activity_id:                     ScenarioMIP
#     contact:                         contact.cmip@meteo.fr
# ...

# %%
ds = xr.open_mfdataset(urls, concat_dim='time', combine='nested', data_vars='all',)
# Out:
# c:\Users\Luc\projects\pyagnps\.venv\Lib\site-packages\xarray\core\concat.py:532: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   result_vars.update(dim_coords)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (lat: 360, lon: 720, time: 31411, axis_nbounds: 2)
# Coordinates:
#   * lat          (lat) float64 -89.62 -89.12 -88.62 -88.13 ... 88.62 89.12 89.62
#   * lon          (lon) float64 0.0 0.5 1.0 1.5 2.0 ... 358.0 358.5 359.0 359.5
#     height       float64 2.0
#   * time         (time) datetime64[ns] 2015-01-01T12:00:00 ... 2100-12-31T12:...
# Dimensions without coordinates: axis_nbounds
# Data variables:
#     time_bounds  (time, axis_nbounds) datetime64[ns] dask.array<chunksize=(18263, 2), meta=np.ndarray>
#     tas          (time, lat, lon) float32 dask.array<chunksize=(18263, 360, 720), meta=np.ndarray>
# Attributes: (12/53)
#     Conventions:                     CF-1.7 CMIP-6.2
#     creation_date:                   2019-09-13T14:50:52Z
#     description:                     Future scenario with high radiative forc...
#     title:                           CNRM-CM6-1-HR model output prepared for ...
# ...

# %%
(ds['tas'].sel(time="2092-11-18", method="nearest").sel(lon=slice(225, 300), lat=slice(20,60))-273.15).plot()

# %%
ds0
# Out:
# <xarray.Dataset>
# Dimensions:      (lat: 360, lon: 720, time: 18263, axis_nbounds: 2)
# Coordinates:
#   * lat          (lat) float64 -89.62 -89.12 -88.62 -88.13 ... 88.62 89.12 89.62
#   * lon          (lon) float64 0.0 0.5 1.0 1.5 2.0 ... 358.0 358.5 359.0 359.5
#     height       float64 ...
#   * time         (time) datetime64[ns] 2015-01-01T12:00:00 ... 2064-12-31T12:...
# Dimensions without coordinates: axis_nbounds
# Data variables:
#     time_bounds  (time, axis_nbounds) datetime64[ns] ...
#     tas          (time, lat, lon) float32 ...
# Attributes: (12/53)
#     Conventions:                     CF-1.7 CMIP-6.2
#     creation_date:                   2019-09-13T14:50:52Z
#     description:                     Future scenario with high radiative forc...
#     title:                           CNRM-CM6-1-HR model output prepared for ...
#     activity_id:                     ScenarioMIP
#     contact:                         contact.cmip@meteo.fr
# ...

# %%
ds1
# Out:
# <xarray.Dataset>
# Dimensions:      (lat: 360, lon: 720, time: 13148, axis_nbounds: 2)
# Coordinates:
#   * lat          (lat) float64 -89.62 -89.12 -88.62 -88.13 ... 88.62 89.12 89.62
#   * lon          (lon) float64 0.0 0.5 1.0 1.5 2.0 ... 358.0 358.5 359.0 359.5
#     height       float64 ...
#   * time         (time) datetime64[ns] 2065-01-01T12:00:00 ... 2100-12-31T12:...
# Dimensions without coordinates: axis_nbounds
# Data variables:
#     time_bounds  (time, axis_nbounds) datetime64[ns] ...
#     tas          (time, lat, lon) float32 ...
# Attributes: (12/53)
#     Conventions:                     CF-1.7 CMIP-6.2
#     creation_date:                   2019-10-16T18:56:28Z
#     description:                     Future scenario with high radiative forc...
#     title:                           CNRM-CM6-1-HR model output prepared for ...
#     activity_id:                     ScenarioMIP
#     contact:                         contact.cmip@meteo.fr
# ...

# %%
data = ds1['tas'].sel(lat=89.0, lon=-34.0+360, method='nearest')

# %%
data = data.to_dataframe()

# %%
data
# Out:
#                            lat  lon  height         tas
# time
# 2065-01-01 12:00:00  89.122671  0.0     2.0  250.293533
# 2065-01-02 12:00:00  89.122671  0.0     2.0  252.419128
# 2065-01-03 12:00:00  89.122671  0.0     2.0  255.992325
# 2065-01-04 12:00:00  89.122671  0.0     2.0  255.438782
# 2065-01-05 12:00:00  89.122671  0.0     2.0  257.877991
# ...                        ...  ...     ...         ...
# 2100-12-27 12:00:00  89.122671  0.0     2.0  269.797882
# 2100-12-28 12:00:00  89.122671  0.0     2.0  271.919220
# 2100-12-29 12:00:00  89.122671  0.0     2.0  272.065155
# 2100-12-30 12:00:00  89.122671  0.0     2.0  270.600922
# 2100-12-31 12:00:00  89.122671  0.0     2.0  271.102875
#
# [13148 rows x 4 columns]
