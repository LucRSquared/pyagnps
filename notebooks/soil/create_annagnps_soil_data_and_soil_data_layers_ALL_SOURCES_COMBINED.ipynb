# %% [markdown]
# This notebook outlines the work flow to obtain soil data from NRCS and format it for the whole US in an AnnAGNPS friendly way

# %%
import os, subprocess

from pathlib import Path
from tqdm import tqdm

import pandas as pd

# %% [markdown]
# - Go to : https://sdmdataaccess.nrcs.usda.gov/Query.aspx
# - Run the following query and download the file by email:
# ```
#     select
#     sa.saverest,
#     l.areasymbol,
#     l.areaname,
#     mu.musym,
#     mu.mukey,
#     hydgrp,
#     kwfact,
#     albedodry_r,
#     (SELECT CASE when min(resdept_r) is null then '>200' else cast(min(resdept_r) as
#     varchar) END
#                 from component left outer join corestrictions on component.cokey =
#     corestrictions.cokey where component.cokey = c.cokey and reskind is not null) as
#     restrictiondepthr,
#     partdensity,
#     c.compname,
#     texdesc,
#     hzdepb_r,
#     dbovendry_r,
#     claytotal_r,
#     silttotal_r,
#     sandtotal_r,
#     (select sum(cf.fragvol_r) as fragvol  FROM chfrags cf WHERE cf.chkey = ch.chkey
#     ) as fragvol,
#     sandvf_r,
#     caco3_r,
#     ksat_r,
#     wthirdbar_r,
#     wfifteenbar_r,
#     om_r,
#     ph1to1h2o_r,
#     c.comppct_r
#
#     FROM
#     legend l INNER JOIN mapunit mu ON mu.lkey = l.lkey
#     LEFT OUTER JOIN sacatalog sa ON sa.areasymbol = l.areasymbol
#     LEFT OUTER JOIN component c ON c.mukey = mu.mukey and c.cokey = (SELECT TOP 1 component.cokey FROM component WHERE
#     component.mukey=mu.mukey ORDER BY component.comppct_r DESC)
#     LEFT OUTER JOIN chorizon ch ON ch.cokey = c.cokey
#     LEFT OUTER JOIN chtexturegrp ct ON ch.chkey=ct.chkey
#
#     WHERE ct.rvindicator = 'yes'
#
#     Order by l.areasymbol, musym, mukey, compname, hzdepb_r
# ```

# %% [markdown]
# Then we will combine the result of that query sent by Kyle Stephens that also contains the data from Raster Soil Survey

# %%
path_to_soil_dir = Path('D:/AIMS/Datasets/Soil/DATABASE_POPULATION_TASKS/SDM_QUERY_AND_NITA_PROCESSING/ALL_US_v2_SSURGO_STATSGO2_RSS/')


path_to_soil_table = path_to_soil_dir / 'raw_query_data' / 'soil_data_ALL_SOURCES_COMBINED_with_mukey.csv'

path_to_split_files = path_to_soil_dir / 'split_files'

path_to_NITA_bin = path_to_soil_dir / 'NITA_v6.00.a.008_release_64-bit_Windows.exe'

# %% [markdown]
# Read Soil Data Table (for the entire US)

# %%
df = pd.read_csv(path_to_soil_table)

# %% [markdown]
# We need to use the mukey instead of musym as the Soil_ID but NITA expects a column called musym so a trick is performed where the mukey column is renamed musym

# %%
df = df.rename(columns={'musym': 'musym_label',
                        'mukey': 'mukey_label'})
df['musym'] = df['mukey_label']

# %% [markdown]
# Remove commas from `compname` and `texdesc` columns so that NITA can process it

# %%
df['compname'] = df['compname'].str.replace(',','')
df['texdesc'] = df['texdesc'].str.replace(',','')

# %% [markdown]
# Write the whole updated table to file but step is not necessary

# %%
path_to_nasis = path_to_soil_dir / 'all_nasis_mukey_trick.csv'
df.to_csv(path_to_nasis, index=False)

# %%
df
# Out:
#                      saverest areasymbol
# 0        8/30/2022 7:52:33 PM      AK600  \
# 1        8/30/2022 7:52:33 PM      AK600
# 2        8/30/2022 7:52:33 PM      AK600
# 3        8/30/2022 7:52:33 PM      AK600
# 4        8/30/2022 7:52:33 PM      AK600
# ...                       ...        ...
# 1231660        5/1/2023 15:31         WI
# 1231661        5/1/2023 15:31         WI
# 1231662        5/1/2023 15:31         WI
# 1231663        5/1/2023 15:31         WI
# 1231664        5/1/2023 15:31         WI
#
#                                       areaname musym_label  mukey_label
# 0        Matanuska-Susitna Valley Area, Alaska         101        50226  \
# 1        Matanuska-Susitna Valley Area, Alaska         101        50226
# 2        Matanuska-Susitna Valley Area, Alaska         101        50226
# 3        Matanuska-Susitna Valley Area, Alaska         101        50226
# 4        Matanuska-Susitna Valley Area, Alaska         102        50227
# ...                                        ...         ...          ...
# 1231660                              Wisconsin       308y9      3314510
# 1231661                              Wisconsin       308y9      3314510
# 1231662                              Wisconsin       308y9      3314510
# 1231663                              Wisconsin       308y9      3314510
# 1231664                              Wisconsin       308y9      3314510
#
#         hydgrp  kwfact  albedodry_r restrictiondepthr  partdensity  ...
# 0            B     NaN         0.30              >200         1.40  ...  \
# 1            B    0.37         0.30              >200         2.65  ...
# 2            B    0.43         0.30              >200         2.65  ...
# 3            B    0.05         0.30              >200         2.65  ...
# 4            B     NaN         0.30              >200         1.40  ...
# ...        ...     ...          ...               ...          ...  ...
# 1231660    B/D    0.43         0.17              >200         2.59  ...
# 1231661    B/D    0.55         0.17              >200         2.63  ...
# 1231662    B/D    0.37         0.17              >200         2.63  ...
# 1231663    B/D    0.24         0.17              >200         2.62  ...
# 1231664    B/D    0.10         0.17              >200         2.65  ...
#
#         fragvol sandvf_r  caco3_r  ksat_r  wthirdbar_r  wfifteenbar_r   om_r
# 0           0.0      NaN      0.0   26.00         45.0           20.0  60.00  \
# 1           2.0     18.0      0.0    9.17         35.0           10.0   7.50
# 2           2.0     18.0      0.0    9.17         40.0           10.0   3.00
# 3          10.0      5.0      0.0   28.23         10.0            2.0   0.50
# 4           0.0      NaN      0.0   26.00         45.0           20.0  60.00
# ...         ...      ...      ...     ...          ...            ...    ...
# 1231660     5.0     11.0      0.0    9.00         24.9            9.8   3.00
# 1231661     5.0     11.0      0.0    9.00         21.8            6.8   0.75
# 1231662     7.0     10.0      0.0   28.00         16.1            7.0   0.25
# 1231663    10.0      4.0      0.0   28.00         17.2            8.5   0.25
# 1231664    22.0     15.0      0.0   91.00          6.4            1.1   0.00
#
#          ph1to1h2o_r  comppct_r    musym
# 0                4.3         90    50226
# 1                5.0         90    50226
# 2                5.6         90    50226
# 3                6.1         90    50226
# 4                4.3         60    50227
# ...              ...        ...      ...
# 1231660          6.0        100  3314510
# 1231661          5.2        100  3314510
# 1231662          6.0        100  3314510
# 1231663          6.0        100  3314510
# 1231664          6.0        100  3314510
#
# [1231665 rows x 27 columns]

# %% [markdown]
# Writing multiple files for combining later on

# %%
area_symbols = df['areasymbol'].unique()

for loc in tqdm(area_symbols):
    outpath = path_to_split_files / f'nasis_{loc}_mukey.csv'
    df[df['areasymbol']==loc].to_csv(outpath, index=False)
# Out:
# 100%|██████████| 3247/3247 [05:03<00:00, 10.71it/s]

# %%
nb_dir = Path('__file__').absolute().parent
os.chdir(nb_dir)

# %% [markdown]
# Run NITA seperately for each generated file

# %%
for label in tqdm(area_symbols):
    os.chdir(nb_dir)
    control_file = path_to_split_files / f'NITA_CONTROL_{label}.csv'

    with control_file.open(mode='a') as file:
        file.write('FILENAME,UNITS_OUT,COMBINE\n')
        file.write(f'nasis_{label}_mukey.csv,1,0\n')

    os.chdir(path_to_split_files)
    command = str(path_to_NITA_bin.absolute()) + f' /f:NITA_CONTROL_{label}.csv'
    subprocess.call(command)

    # Rename Excluded Soil Records file so it doesn't get overwritten
    path_to_rename_file = path_to_split_files / 'NITA_Excluded_Soil_Records.csv'
    path_to_rename_file.rename(path_to_rename_file.name.replace('.csv', f'_nasis_{label}_mukey.csv'))

os.chdir(nb_dir)
# Out:
# 100%|██████████| 3247/3247 [10:50<00:00,  4.99it/s]

# %% [markdown]
# Combine all `*_soil_data.csv` and `*_soil_layers_data.csv`

# %%
soil_data_files = list(path_to_split_files.glob('*_mukey_soil_data.csv'))
soil_layers_data_files = list(path_to_split_files.glob('*_mukey_soil_layers_data.csv'))

for f_d, f_l in zip(soil_data_files,soil_layers_data_files):
    if f_d.stat().st_size*f_l.stat().st_size == 0:
        print(f'Problem with files: {f_d.name} and {f_l.name} (empty)')
# Out:
# Problem with files: nasis_AK651_mukey_soil_data.csv and nasis_AK651_mukey_soil_layers_data.csv (empty)
# Problem with files: nasis_FL_mukey_soil_data.csv and nasis_FL_mukey_soil_layers_data.csv (empty)

# %%
df_soil_data = pd.concat([pd.read_csv(f) for f in soil_data_files if f.stat().st_size != 0])
df_soil_layers_data = pd.concat([pd.read_csv(f) for f in soil_layers_data_files if f.stat().st_size != 0])

# %%
df_soil_data = df_soil_data.drop_duplicates().reset_index(drop=True)
df_soil_layers_data = df_soil_layers_data.drop_duplicates().reset_index(drop=True)

# %%
df_soil_data
# Out:
#         Soil_ID Hydrologic_Soil_Group  K_Factor  Albedo
# 0         50226                     B    0.0487    0.30  \
# 1         50227                     B    0.0487    0.30
# 2         50229                     B    0.0487    0.30
# 3         50231                     B    0.0487    0.30
# 4         50233                     B    0.0487    0.23
# ...         ...                   ...       ...     ...
# 307783  3222362                     C    0.0724    0.30
# 307784  3222363                     C    0.0566    0.23
# 307785  3222364                     C    0.0645    0.23
# 307786  3222366                     D    0.0421    0.23
# 307787  3222367                     D    0.0487    0.23
#
#         Time_to_Consolidation  Impervious_Depth  Specific_Gravity
# 0                         NaN               NaN               NaN  \
# 1                         NaN               NaN               NaN
# 2                         NaN               NaN               NaN
# 3                         NaN               NaN               NaN
# 4                         NaN            1270.0               NaN
# ...                       ...               ...               ...
# 307783                    NaN               NaN               NaN
# 307784                    NaN               NaN               NaN
# 307785                    NaN               NaN               NaN
# 307786                    NaN             180.0               NaN
# 307787                    NaN             160.0               NaN
#
#         Initial_Soil_Conditions_ID   Soil_Name                  Soil_Texture
# 0                              NaN       Benka                     Silt loam  \
# 1                              NaN       Benka                     Silt loam
# 2                              NaN       Benka                     Silt loam
# 3                              NaN       Benka                     Silt loam
# 4                              NaN   Bodenburg                     Silt loam
# ...                            ...         ...                           ...
# 307783                         NaN   Saltwells                     Silt loam
# 307784                         NaN   Saltwells                          Loam
# 307785                         NaN   Saltwells                          Loam
# 307786                         NaN  Rangecreek  Paragravelly fine sandy loam
# 307787                         NaN     Cabbart         Stony silty clay loam
#
#         Number_of_Soil_Layers  Input_Units_Code
# 0                           3                 1
# 1                           3                 1
# 2                           3                 1
# 3                           3                 1
# 4                           3                 1
# ...                       ...               ...
# 307783                      7                 1
# 307784                      7                 1
# 307785                      6                 1
# 307786                      2                 1
# 307787                      2                 1
#
# [307788 rows x 12 columns]

# %%
n_soils = len(df_soil_data['Soil_ID'].unique())
print(f'Number of unique Soil_IDs after processing = {n_soils}')
# Out:
# Number of unique Soil_IDs after processing = 307788

# %%
df_soil_layers_data
# Out:
#          Soil_ID  Layer_Number  Layer_Depth  Bulk_Density  Clay_Ratio
# 0          50226             1        120.0          0.88        0.05  \
# 1          50226             2        760.0          0.88        0.05
# 2          50226             3       1520.0          1.43        0.02
# 3          50227             1        120.0          0.88        0.05
# 4          50227             2        760.0          0.88        0.05
# ...          ...           ...          ...           ...         ...
# 1100662  3222364             6       2000.0          1.62        0.32
# 1100663  3222366             1         50.0          1.54        0.15
# 1100664  3222366             2        180.0          1.54        0.23
# 1100665  3222367             1         50.0          1.58        0.29
# 1100666  3222367             2        160.0          1.52        0.30
#
#          Silt_Ratio  Sand_Ratio  Rock_Ratio  Very_Fine_Sand_Ratio
# 0              0.62        0.33        0.02                 0.180  \
# 1              0.62        0.33        0.02                 0.180
# 2              0.06        0.92        0.10                 0.050
# 3              0.62        0.33        0.02                 0.180
# 4              0.62        0.33        0.02                 0.180
# ...             ...         ...         ...                   ...
# 1100662        0.58        0.10         NaN                 0.068
# 1100663        0.15        0.70        0.25                 0.171
# 1100664        0.37        0.40        0.50                 0.118
# 1100665        0.61        0.10        0.15                 0.061
# 1100666        0.60        0.10        0.15                 0.061
#
#          CaCO3_Content  ...  Base_Saturation  Unstable_Aggregate_Ratio   pH
# 0                 0.00  ...              NaN                       NaN  5.0  \
# 1                 0.00  ...              NaN                       NaN  5.6
# 2                 0.00  ...              NaN                       NaN  6.1
# 3                 0.00  ...              NaN                       NaN  5.0
# 4                 0.00  ...              NaN                       NaN  5.6
# ...                ...  ...              ...                       ...  ...
# 1100662           0.20  ...              NaN                       NaN  8.6
# 1100663           0.04  ...              NaN                       NaN  7.8
# 1100664           0.10  ...              NaN                       NaN  7.8
# 1100665           0.20  ...              NaN                       NaN  8.2
# 1100666           0.20  ...              NaN                       NaN  8.2
#
#          Organic_Matter_Ratio  Organic_N_Ratio  Inorganic_N_Ratio
# 0                       0.075              NaN                NaN  \
# 1                       0.030              NaN                NaN
# 2                       0.005              NaN                NaN
# 3                       0.075              NaN                NaN
# 4                       0.030              NaN                NaN
# ...                       ...              ...                ...
# 1100662                 0.001              NaN                NaN
# 1100663                 0.005              NaN                NaN
# 1100664                 0.002              NaN                NaN
# 1100665                 0.005              NaN                NaN
# 1100666                 0.002              NaN                NaN
#
#          Organic_P_Ratio  Inorganic_P_Ratio  Soil_Structure_Code
# 0                    NaN                NaN                  NaN  \
# 1                    NaN                NaN                  NaN
# 2                    NaN                NaN                  NaN
# 3                    NaN                NaN                  NaN
# 4                    NaN                NaN                  NaN
# ...                  ...                ...                  ...
# 1100662              NaN                NaN                  NaN
# 1100663              NaN                NaN                  NaN
# 1100664              NaN                NaN                  NaN
# 1100665              NaN                NaN                  NaN
# 1100666              NaN                NaN                  NaN
#
#          Input_Units_Code
# 0                       1
# 1                       1
# 2                       1
# 3                       1
# 4                       1
# ...                   ...
# 1100662                 1
# 1100663                 1
# 1100664                 1
# 1100665                 1
# 1100666                 1
#
# [1100667 rows x 24 columns]

# %%
df_soil_data.to_parquet(path_to_soil_dir / 'all_valid_soil_data.parquet')
df_soil_layers_data.to_parquet(path_to_soil_dir / 'all_valid_soil_layers_data.parquet')

df_soil_data.to_csv(path_to_soil_dir / 'all_valid_soil_data.csv', index=False)
df_soil_layers_data.to_csv(path_to_soil_dir / 'all_valid_soil_layers_data.csv', index=False)
