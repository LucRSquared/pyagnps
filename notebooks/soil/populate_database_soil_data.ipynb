# %%
from pathlib import Path
import json
import pandas as pd
from sqlalchemy import URL, create_engine, text as sql_text

# %%
credentials = Path('../../inputs/db_credentials.json')
with open(credentials, 'r') as f:
    credentials = json.load(f)

user     = credentials['user']
password = credentials['password']
host     = credentials['host']
port     = credentials['port']
database = credentials['database']

# %%
# root_dir = Path('C:/Users/Luc/projects/pyagnps/inputs/soil/ALL_US_v3_SSURGO_STATSGO2_RSS')
root_dir = Path('D:/AIMS/Datasets/Soil/DATABASE_POPULATION_TASKS/SDM_QUERY_AND_NITA_PROCESSING/ALL_US_v3_SSURGO_STATSGO2_RSS/')

path_to_parquet_soil_data = root_dir / 'all_valid_soil_data.parquet'
soil_data_db_name = 'usa_valid_soil_data'

path_to_parquet_soil_layers_data = root_dir / 'all_valid_soil_layers_data.parquet'
soil_layers_data_db_name = 'usa_valid_soil_layers_data'

path_to_raw_soil_complete = root_dir / 'raw_query_data' / 'all_raw_soil_data_no_rvindicator_condition_STATSGO2_SSURGO_RSS.parquet'
raw_soil_complete_db_name = 'raw_nrcs_soil_data'

# %%
df_soil = pd.read_parquet(path_to_parquet_soil_data)
df_soil.head()
# Out:
#    Soil_ID Hydrologic_Soil_Group  K_Factor  Albedo  Time_to_Consolidation  \
# 0    50226                     B    0.0487    0.30                    NaN
# 1    50227                     B    0.0487    0.30                    NaN
# 2    50229                     B    0.0487    0.30                    NaN
# 3    50231                     B    0.0487    0.30                    NaN
# 4    50233                     B    0.0487    0.23                    NaN
#
#    Impervious_Depth  Specific_Gravity  Initial_Soil_Conditions_ID  Soil_Name  \
# 0               NaN               NaN                         NaN      Benka
# 1               NaN               NaN                         NaN      Benka
# 2               NaN               NaN                         NaN      Benka
# 3               NaN               NaN                         NaN      Benka
# 4            1270.0               NaN                         NaN  Bodenburg
#
#   Soil_Texture  Number_of_Soil_Layers  Input_Units_Code
# 0    Silt loam                      3                 1
# 1    Silt loam                      3                 1
# 2    Silt loam                      3                 1
# 3    Silt loam                      3                 1
# 4    Silt loam                      3                 1

# %%
df_soil_layers = pd.read_parquet(path_to_parquet_soil_layers_data)
df_soil_layers.head()
# Out:
#    Soil_ID  Layer_Number  Layer_Depth  Bulk_Density  Clay_Ratio  Silt_Ratio  \
# 0    50226             1        120.0          0.88        0.05        0.62
# 1    50226             2        760.0          0.88        0.05        0.62
# 2    50226             3       1520.0          1.43        0.02        0.06
# 3    50227             1        120.0          0.88        0.05        0.62
# 4    50227             2        760.0          0.88        0.05        0.62
#
#    Sand_Ratio  Rock_Ratio  Very_Fine_Sand_Ratio  CaCO3_Content  ...  \
# 0        0.33        0.02                  0.18            0.0  ...
# 1        0.33        0.02                  0.18            0.0  ...
# 2        0.92        0.10                  0.05            0.0  ...
# 3        0.33        0.02                  0.18            0.0  ...
# 4        0.33        0.02                  0.18            0.0  ...
#
#    Base_Saturation  Unstable_Aggregate_Ratio   pH  Organic_Matter_Ratio  \
# 0              NaN                       NaN  5.0                 0.075
# 1              NaN                       NaN  5.6                 0.030
# 2              NaN                       NaN  6.1                 0.005
# 3              NaN                       NaN  5.0                 0.075
# 4              NaN                       NaN  5.6                 0.030
#
#    Organic_N_Ratio  Inorganic_N_Ratio  Organic_P_Ratio  Inorganic_P_Ratio  \
# 0              NaN                NaN              NaN                NaN
# 1              NaN                NaN              NaN                NaN
# 2              NaN                NaN              NaN                NaN
# 3              NaN                NaN              NaN                NaN
# 4              NaN                NaN              NaN                NaN
#
#    Soil_Structure_Code  Input_Units_Code
# 0                  NaN                 1
# 1                  NaN                 1
# 2                  NaN                 1
# 3                  NaN                 1
# 4                  NaN                 1
#
# [5 rows x 24 columns]

# %%
df_raw = pd.read_parquet(path_to_raw_soil_complete)
df_raw.head()
# Out:
#                saverest areasymbol                               areaname  \
# 0  8/30/2022 7:52:33 PM      AK600  Matanuska-Susitna Valley Area, Alaska
# 1  8/30/2022 7:52:33 PM      AK600  Matanuska-Susitna Valley Area, Alaska
# 2  8/30/2022 7:52:33 PM      AK600  Matanuska-Susitna Valley Area, Alaska
# 3  8/30/2022 7:52:33 PM      AK600  Matanuska-Susitna Valley Area, Alaska
# 4  8/30/2022 7:52:33 PM      AK600  Matanuska-Susitna Valley Area, Alaska
#
#   musym  mukey hydgrp  kwfact  albedodry_r restrictiondepthr  partdensity  \
# 0   101  50226      B     NaN          0.3              >200         1.40
# 1   101  50226      B    0.37          0.3              >200         2.65
# 2   101  50226      B    0.43          0.3              >200         2.65
# 3   101  50226      B    0.05          0.3              >200         2.65
# 4   102  50227      B     NaN          0.3              >200         1.40
#
#    ... sandtotal_r fragvol  sandvf_r  caco3_r  ksat_r  wthirdbar_r  \
# 0  ...         NaN     0.0       NaN      0.0   26.00         45.0
# 1  ...        33.0     2.0      18.0      0.0    9.17         35.0
# 2  ...        33.0     2.0      18.0      0.0    9.17         40.0
# 3  ...        92.0    10.0       5.0      0.0   28.23         10.0
# 4  ...         NaN     0.0       NaN      0.0   26.00         45.0
#
#    wfifteenbar_r  om_r  ph1to1h2o_r  comppct_r
# 0           20.0  60.0          4.3         90
# 1           10.0   7.5          5.0         90
# 2           10.0   3.0          5.6         90
# 3            2.0   0.5          6.1         90
# 4           20.0  60.0          4.3         60
#
# [5 rows x 26 columns]

# %% [markdown]
# Create db connection engine

# %%
url_object = URL.create(
    "postgresql",
    username=user,
    password=password,
    host=host,
    port=port,
    database=database
)

# create a SQLAlchemy engine object
engine = create_engine(url_object)

# %% [markdown]
# Populate `usa_valid_soil_data` table

# %%
# create a new table in the database
with engine.connect() as conn:
    # start a transaction
    trans = conn.begin()

    try:
        # create a table with the same column names and data types as the DataFrame
        df_soil.to_sql(name=soil_data_db_name, con=conn, index=False, if_exists='replace')

        # commit the transaction if there were no errors
        trans.commit()

    except Exception as e:
        # rollback the transaction if there was an error
        trans.rollback()
        raise e

# %% [markdown]
# Populate `usa_valid_soil_layers_data` table

# %%
# create a new table in the database
with engine.connect() as conn:
    # start a transaction
    trans = conn.begin()

    try:
        # create a table with the same column names and data types as the DataFrame
        df_soil_layers.to_sql(name=soil_layers_data_db_name, con=conn, index=False, if_exists='replace')

        # commit the transaction if there were no errors
        trans.commit()

    except Exception as e:
        # rollback the transaction if there was an error
        trans.rollback()
        raise e

# %% [markdown]
# Populate `raw_nrcs_soil_data`

# %%
df_raw = df_raw.drop(columns=['saverest'])

# %%
# create a new table in the database
with engine.connect() as conn:
    # start a transaction
    trans = conn.begin()

    try:
        # create a table with the same column names and data types as the DataFrame
        df_raw.to_sql(name=raw_soil_complete_db_name, con=conn, index=False, if_exists='replace')

        # commit the transaction if there were no errors
        trans.commit()

    except Exception as e:
        # rollback the transaction if there was an error
        trans.rollback()
        raise e

# %% [markdown]
# Check that it worked

# %%
query = f"SELECT * FROM {soil_data_db_name} LIMIT 100"

with engine.connect() as conn:

    try:

        df_soil_check = pd.read_sql_query(sql=sql_text(query), con=conn)

    except Exception as e:

        raise e

# %%
df_soil_check
# Out:
#     Soil_ID Hydrologic_Soil_Group  K_Factor  Albedo Time_to_Consolidation  \
# 0     50226                     B    0.0487    0.30                  None
# 1     50227                     B    0.0487    0.30                  None
# 2     50229                     B    0.0487    0.30                  None
# 3     50231                     B    0.0487    0.30                  None
# 4     50233                     B    0.0487    0.23                  None
# ..      ...                   ...       ...     ...                   ...
# 95    50326                  None -999.0000     NaN                  None
# 96    50327                     B    0.0487    0.30                  None
# 97    50328                     B    0.0487    0.30                  None
# 98    50329                     B    0.0487    0.30                  None
# 99    50331                     B    0.0487    0.30                  None
#
#     Impervious_Depth Specific_Gravity Initial_Soil_Conditions_ID  Soil_Name  \
# 0                NaN             None                       None      Benka
# 1                NaN             None                       None      Benka
# 2                NaN             None                       None      Benka
# 3                NaN             None                       None      Benka
# 4             1270.0             None                       None  Bodenburg
# ..               ...              ...                        ...        ...
# 95               NaN             None                       None       None
# 96               NaN             None                       None  Tokositna
# 97               NaN             None                       None  Tokositna
# 98               NaN             None                       None  Tokositna
# 99               NaN             None                       None  Tokositna
#
#    Soil_Texture  Number_of_Soil_Layers  Input_Units_Code
# 0     Silt loam                      3                 1
# 1     Silt loam                      3                 1
# 2     Silt loam                      3                 1
# 3     Silt loam                      3                 1
# 4     Silt loam                      3                 1
# ..          ...                    ...               ...
# 95         Muck                      1                 1
# 96    Silt loam                      3                 1
# 97    Silt loam                      3                 1
# 98    Silt loam                      3                 1
# 99    Silt loam                      3                 1
#
# [100 rows x 12 columns]

# %%
query = f"SELECT * FROM {soil_layers_data_db_name} LIMIT 100"

with engine.connect() as conn:

    try:

        df_soil_layers_check = pd.read_sql_query(sql=sql_text(query), con=conn)

    except Exception as e:

        raise e

# %%
df_soil_layers_check
# Out:
#     Soil_ID  Layer_Number  Layer_Depth  Bulk_Density  Clay_Ratio  Silt_Ratio  \
# 0     50226             1        120.0          0.88        0.05        0.62
# 1     50226             2        760.0          0.88        0.05        0.62
# 2     50226             3       1520.0          1.43        0.02        0.06
# 3     50227             1        120.0          0.88        0.05        0.62
# 4     50227             2        760.0          0.88        0.05        0.62
# ..      ...           ...          ...           ...         ...         ...
# 95    50267             3       1520.0          1.20        0.02        0.44
# 96    50268             1        130.0          0.80        0.03        0.64
# 97    50268             2        310.0          0.80        0.03        0.64
# 98    50268             3       1520.0          1.20        0.02        0.44
# 99    49967             1        130.0          0.18      999.00      999.00
#
#     Sand_Ratio  Rock_Ratio  Very_Fine_Sand_Ratio  CaCO3_Content  ...  \
# 0         0.33        0.02                  0.18            0.0  ...
# 1         0.33        0.02                  0.18            0.0  ...
# 2         0.92        0.10                  0.05            0.0  ...
# 3         0.33        0.02                  0.18            0.0  ...
# 4         0.33        0.02                  0.18            0.0  ...
# ..         ...         ...                   ...            ...  ...
# 95        0.54        0.10                  0.30            0.0  ...
# 96        0.33        0.08                  0.18            0.0  ...
# 97        0.33        0.08                  0.18            0.0  ...
# 98        0.54        0.10                  0.30            0.0  ...
# 99      999.00         NaN                   NaN            NaN  ...
#
#     Base_Saturation  Unstable_Aggregate_Ratio   pH Organic_Matter_Ratio  \
# 0              None                      None  5.0                0.075
# 1              None                      None  5.6                0.030
# 2              None                      None  6.1                0.005
# 3              None                      None  5.0                0.075
# 4              None                      None  5.6                0.030
# ..              ...                       ...  ...                  ...
# 95             None                      None  5.6                0.010
# 96             None                      None  5.0                0.060
# 97             None                      None  5.0                0.020
# 98             None                      None  5.6                0.010
# 99             None                      None  NaN                  NaN
#
#    Organic_N_Ratio Inorganic_N_Ratio  Organic_P_Ratio  Inorganic_P_Ratio  \
# 0             None              None             None               None
# 1             None              None             None               None
# 2             None              None             None               None
# 3             None              None             None               None
# 4             None              None             None               None
# ..             ...               ...              ...                ...
# 95            None              None             None               None
# 96            None              None             None               None
# 97            None              None             None               None
# 98            None              None             None               None
# 99            None              None             None               None
#
#    Soil_Structure_Code Input_Units_Code
# 0                 None                1
# 1                 None                1
# 2                 None                1
# 3                 None                1
# 4                 None                1
# ..                 ...              ...
# 95                None                1
# 96                None                1
# 97                None                1
# 98                None                1
# 99                None                1
#
# [100 rows x 24 columns]

# %%
query = f"SELECT * FROM {raw_soil_complete_db_name} LIMIT 100"

with engine.connect() as conn:

    try:

        df_raw_check = pd.read_sql_query(sql=sql_text(query), con=conn)

    except Exception as e:

        raise e

# %%
df_raw_check
# Out:
#    areasymbol                               areaname musym  mukey hydgrp  \
# 0       AK600  Matanuska-Susitna Valley Area, Alaska   101  50226      B
# 1       AK600  Matanuska-Susitna Valley Area, Alaska   101  50226      B
# 2       AK600  Matanuska-Susitna Valley Area, Alaska   101  50226      B
# 3       AK600  Matanuska-Susitna Valley Area, Alaska   101  50226      B
# 4       AK600  Matanuska-Susitna Valley Area, Alaska   102  50227      B
# ..        ...                                    ...   ...    ...    ...
# 95      AK600  Matanuska-Susitna Valley Area, Alaska   127  50257      A
# 96      AK600  Matanuska-Susitna Valley Area, Alaska   127  50257      A
# 97      AK600  Matanuska-Susitna Valley Area, Alaska   127  50257      A
# 98      AK600  Matanuska-Susitna Valley Area, Alaska   127  50257      A
# 99      AK600  Matanuska-Susitna Valley Area, Alaska   128  50258      D
#
#     kwfact  albedodry_r restrictiondepthr  partdensity    compname  ...  \
# 0      NaN         0.30              >200         1.40       Benka  ...
# 1     0.37         0.30              >200         2.65       Benka  ...
# 2     0.43         0.30              >200         2.65       Benka  ...
# 3     0.05         0.30              >200         2.65       Benka  ...
# 4      NaN         0.30              >200         1.40       Benka  ...
# ..     ...          ...               ...          ...         ...  ...
# 95     NaN         0.23              >200         1.40    Delyndia  ...
# 96    0.37         0.23              >200         2.65    Delyndia  ...
# 97    0.43         0.23              >200         2.65    Delyndia  ...
# 98    0.05         0.23              >200         2.65    Delyndia  ...
# 99     NaN         0.16                79         2.64  Disappoint  ...
#
#    sandtotal_r  fragvol  sandvf_r  caco3_r  ksat_r  wthirdbar_r  \
# 0          NaN      0.0       NaN      0.0   26.00         45.0
# 1         33.0      2.0      18.0      0.0    9.17         35.0
# 2         33.0      2.0      18.0      0.0    9.17         40.0
# 3         92.0     10.0       5.0      0.0   28.23         10.0
# 4          NaN      0.0       NaN      0.0   26.00         45.0
# ..         ...      ...       ...      ...     ...          ...
# 95         NaN      0.0       NaN      0.0   26.00         45.0
# 96        33.0      2.0      18.0      0.0    9.17         35.0
# 97        33.0      2.0      18.0      0.0    9.17         40.0
# 98        92.0     16.0       5.0      0.0   28.23         10.0
# 99         NaN      0.0       NaN      0.0   26.00         45.0
#
#     wfifteenbar_r  om_r  ph1to1h2o_r  comppct_r
# 0            20.0  60.0          4.3         90
# 1            10.0   7.5          5.0         90
# 2            10.0   3.0          5.6         90
# 3             2.0   0.5          6.1         90
# 4            20.0  60.0          4.3         60
# ..            ...   ...          ...        ...
# 95           20.0  60.0          5.0         50
# 96           10.0   6.0          5.0         50
# 97           10.0   3.0          5.6         50
# 98            2.0   1.0          6.5         50
# 99           20.0  85.0          3.9         90
#
# [100 rows x 25 columns]
