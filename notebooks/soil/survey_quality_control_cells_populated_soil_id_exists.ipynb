# %%
import json
from pathlib import Path

from tqdm import tqdm

import geopandas as gpd
import pandas as pd

from pyagnps import soil_data_market as sdm

from sqlalchemy import create_engine, text as sql_text

# %%
# DATABASE SETUP
credentials = Path("../../inputs/db_credentials_old.json")
with open(credentials, "r") as f:
    credentials = json.load(f)

user = credentials["user"]
password = credentials["password"]
host = credentials["host"]
port = credentials["port"]
database = credentials["database"]

engine = create_engine(f"postgresql://{user}:{password}@{host}:{port}/{database}")

# %%
# path_to_thucs = Path(
#     "D:/AIMS/Datasets/THUCS_TopAGNPS_Delineations/40k_SM/tophuc_S_M_40000_closed_holes_with_container_thuc_merged_bbox_area_first_kept.gpkg"
# )
path_to_thucs = Path('../../inputs/thucs/tophuc_S_M_40000_closed_holes_with_container_thuc_merged_bbox_area_first_kept.gpkg')

thucs = gpd.read_file(
    path_to_thucs
)  # GeoDataFrame containing the thucs and their geometry
thucs = thucs.sort_values(by=["bbox_area_sqkm"], ascending=False)

runlist = thucs['tophucid'].to_list()

# %%
runlist = ['1809']

# %% [markdown]
# ### Method 1 to get valid Soil IDs : Query database

# %%
# Fetch the list of valid Soil_ID values from usa_valid_soil_data
soil_ids_query = """SELECT DISTINCT "Soil_ID" FROM usa_valid_soil_data"""
soil_ids_df = pd.read_sql(soil_ids_query, engine)
soil_ids = soil_ids_df['Soil_ID'].tolist()

# %%
len(soil_ids)
# Out:
# 307577

# %% [markdown]
# ### Method 2 to get valid Soil IDs: Read parquet file

# %%
path_to_NITA_processed_soil_data = Path('D:/AIMS/Datasets/Soil/DATABASE_POPULATION_TASKS/SDM_QUERY_AND_NITA_PROCESSING/ALL_US_v2_SSURGO_STATSGO2_RSS/all_valid_soil_data.parquet')
df_soil_data = pd.read_parquet(path_to_NITA_processed_soil_data)
soil_ids = df_soil_data['Soil_ID'].tolist()
len(soil_ids)
# Out:
# 307788

# %% [markdown]
# ### Reading NITA discarded records

# %%
path_to_NITA_discarded = Path('D:/AIMS/Datasets/Soil/DATABASE_POPULATION_TASKS/SDM_QUERY_AND_NITA_PROCESSING/ALL_US_v2_SSURGO_STATSGO2_RSS/nita_excluded_soil_ids_mukey.parquet')
df_nita_discarded = pd.read_parquet(path_to_NITA_discarded)
df_nita_discarded = df_nita_discarded.drop_duplicates(subset='soil_id', keep='first')

# %%
discarded_soil_ids = df_nita_discarded['soil_id'].tolist()

# %%
'567304' in soil_ids
# Out:
# False

# %%
thuc_id = '1148' #'1060' #'1481' #'0200' #'1569' #'1128' #'1569' #'1769' #'1809'

# %%
rows_invalid_soil_id = []

# Query cells that have soil_id populated
query_cds = f"SELECT cell_id, soil_id FROM thuc_{thuc_id}_annagnps_cell_data_section WHERE soil_id IS NOT NULL"


with engine.connect() as conn:
    # query all populated cells
    cell_data_section = pd.read_sql(sql=sql_text(query_cds), con=conn)
    # filter out the cells that have a soil_id in in usa_valid_soil_data
    cell_data_section = cell_data_section[~cell_data_section['soil_id'].isin(soil_ids)]

    populated_invalid_cells = cell_data_section['cell_id'].to_list()
    # populated_invalid_soils = cell_data_section['soil_id'].to_list()

    if populated_invalid_cells:

        query_geom = "SELECT dn, geom FROM thuc_{}_annagnps_cell_ids WHERE dn in ({})"\
            .format(thuc_id, ','.join(str(x) for x in populated_invalid_cells))


        cells = gpd.read_postgis(sql=sql_text(query_geom), con=conn, geom_col="geom")
        cells = cells.to_crs('epsg:4326')
        cells['thuc'] = thuc_id

        invalid_rows = cells.merge(cell_data_section, left_on='dn', right_on='cell_id')
        invalid_rows = invalid_rows[['geom', 'thuc', 'cell_id', 'soil_id']]

        rows_invalid_soil_id.append(invalid_rows)

# %% [markdown]
# ## Merge with discarded NITA files

# %%
invalid_rows_copy = invalid_rows.copy(deep=True)
invalid_rows_copy['soil_id'] = invalid_rows_copy['soil_id'].astype(str)

invalid_rows_copy = invalid_rows_copy.merge(df_nita_discarded, how='left', on='soil_id')

# %%
invalid_rows_copy
# Out:
#                                                      geom  thuc  cell_id
# 0       POLYGON ((-89.82490 34.98747, -89.82491 34.987...  1148   664103  \
# 1       POLYGON ((-90.23222 34.99988, -90.23232 34.996...  1148   638721
# 2       POLYGON ((-89.81792 34.98945, -89.81794 34.988...  1148   664162
# 3       POLYGON ((-90.23617 34.99970, -90.23620 34.998...  1148   638472
# 4       POLYGON ((-89.82126 34.98818, -89.82128 34.987...  1148   664142
# ...                                                   ...   ...      ...
# 120227  POLYGON ((-90.90811 32.32047, -90.90812 32.320...  1148       32
# 120228  POLYGON ((-90.90702 32.32613, -90.90704 32.325...  1148       42
# 120229  POLYGON ((-90.90808 32.32155, -90.90809 32.321...  1148       33
# 120230  POLYGON ((-90.89814 32.32463, -90.89814 32.324...  1148       43
# 120231  POLYGON ((-90.90843 32.32047, -90.90843 32.320...  1148       22
#
#         soil_id                       problems
# 0       1907932                            NaN
# 1        567304                            NaN
# 2        567754  missing hydrologic soil group
# 3        567304                            NaN
# 4        567754  missing hydrologic soil group
# ...         ...                            ...
# 120227   808562                            NaN
# 120228   808562                            NaN
# 120229   808562                            NaN
# 120230   633319                            NaN
# 120231   808562                            NaN
#
# [120232 rows x 5 columns]

# %%
# invalid_rows_copy.explore(column='problems')

# %%
invalid_rows_copy[~invalid_rows_copy['problems'].isna()]
# Out:
# Empty GeoDataFrame
# Columns: [geom, thuc, cell_id, soil_id, problems]
# Index: []

# %%
# Fetch the list of valid Soil_ID values from usa_valid_soil_data
raw_mukey_query = """SELECT * FROM raw_nrcs_soil_data WHERE mukey in (2532950, 2501314, 2498837, 2498619, 382198, 128022, 139817)"""
df_mukey = pd.read_sql(raw_mukey_query, engine)
df_mukey
# Out:
#   areasymbol                   areaname musym   mukey hydgrp kwfact
# 0      OK031  Comanche County, Oklahoma    Ro  382198      D   None  \
#
#   albedodry_r restrictiondepthr partdensity      compname  ... sandtotal_r
# 0        None                 0        None  Rock outcrop  ...        None  \
#
#    fragvol sandvf_r caco3_r ksat_r wthirdbar_r wfifteenbar_r  om_r
# 0     None     None    None  0.217        None          None  None  \
#
#   ph1to1h2o_r  comppct_r
# 0        None         70
#
# [1 rows x 25 columns]

# %%
# Fetch the list of valid Soil_ID values from usa_valid_soil_data
soil_id_query = """SELECT * FROM usa_valid_soil_data WHERE "Soil_ID" = 2532950"""
df_mukey = pd.read_sql(soil_id_query, engine)
df_mukey
# Out:
# ---------------------------------------------------------------------------
# PendingRollbackError                      Traceback (most recent call last)
# Cell In[128], line 3
#       1 # Fetch the list of valid Soil_ID values from usa_valid_soil_data
#       2 soil_id_query = """SELECT * FROM usa_valid_soil_data WHERE "Soil_ID" = 2532950"""
# ----> 3 df_mukey = pd.read_sql(soil_id_query, engine)
#       4 df_mukey
#
# File c:\Users\Luc\projects\pyagnps\.venv\Lib\site-packages\pandas\io\sql.py:661, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     651     return pandas_sql.read_table(
#     652         sql,
#     653         index_col=index_col,
#    (...)
#     658         dtype_backend=dtype_backend,
#     659     )
#     660 else:
# --> 661     return pandas_sql.read_query(
#     662         sql,
#     663         index_col=index_col,
#     664         params=params,
#     665         coerce_float=coerce_float,
#     666         parse_dates=parse_dates,
#     667         chunksize=chunksize,
#     668         dtype_backend=dtype_backend,
#     669         dtype=dtype,
#     670     )
#
# File c:\Users\Luc\projects\pyagnps\.venv\Lib\site-packages\pandas\io\sql.py:1736, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1679 def read_query(
#    1680     self,
#    1681     sql: str,
#    (...)
#    1688     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    1689 ) -> DataFrame | Iterator[DataFrame]:
#    1690     """
#    1691     Read SQL query into a DataFrame.
#    1692
#    (...)
#    1734
#    1735     """
# -> 1736     result = self.execute(sql, params)
#    1737     columns = result.keys()
#    1739     if chunksize is not None:
#
# File c:\Users\Luc\projects\pyagnps\.venv\Lib\site-packages\pandas\io\sql.py:1560, in SQLDatabase.execute(self, sql, params)
#    1558 args = [] if params is None else [params]
#    1559 if isinstance(sql, str):
# -> 1560     return self.con.exec_driver_sql(sql, *args)
#    1561 return self.con.execute(sql, *args)
#
# File c:\Users\Luc\projects\pyagnps\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1771, in Connection.exec_driver_sql(self, statement, parameters, execution_options)
#    1766 execution_options = self._execution_options.merge_with(
#    1767     execution_options
#    1768 )
#    1770 dialect = self.dialect
# -> 1771 ret = self._execute_context(
#    1772     dialect,
#    1773     dialect.execution_ctx_cls._init_statement,
#    1774     statement,
#    1775     None,
#    1776     execution_options,
#    1777     statement,
#    1778     distilled_parameters,
#    1779 )
#    1781 return ret
#
# File c:\Users\Luc\projects\pyagnps\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1805, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1803     conn = self._dbapi_connection
#    1804     if conn is None:
# -> 1805         conn = self._revalidate_connection()
#    1807     context = constructor(
#    1808         dialect, self, conn, execution_options, *args, **kw
#    1809     )
#    1810 except (exc.PendingRollbackError, exc.ResourceClosedError):
#
# File c:\Users\Luc\projects\pyagnps\.venv\Lib\site-packages\sqlalchemy\engine\base.py:665, in Connection._revalidate_connection(self)
#     663 if self.__can_reconnect and self.invalidated:
#     664     if self._transaction is not None:
# --> 665         self._invalid_transaction()
#     666     self._dbapi_connection = self.engine.raw_connection()
#     667     return self._dbapi_connection
#
# File c:\Users\Luc\projects\pyagnps\.venv\Lib\site-packages\sqlalchemy\engine\base.py:655, in Connection._invalid_transaction(self)
#     654 def _invalid_transaction(self) -> NoReturn:
# --> 655     raise exc.PendingRollbackError(
#     656         "Can't reconnect until invalid %stransaction is rolled "
#     657         "back.  Please rollback() fully before proceeding"
#     658         % ("savepoint " if self._nested_transaction is not None else ""),
#     659         code="8s2b",
#     660     )
#
# PendingRollbackError: Can't reconnect until invalid transaction is rolled back.  Please rollback() fully before proceeding (Background on this error at: https://sqlalche.me/e/20/8s2b)

# %%
thucs.sort_values(by='bbox_area_sqkm', ascending=True)
# Out:
#      tophucid  drainage_area_sqkm   outlethuc12 outlethuc12_hutype
# 4774     4780                7.07  210100040502                  S  \
# 4789     4795                7.45  210100050301                  S
# 4779     4785               13.58  210100040509                  S
# 4775     4781               11.92  210100040503                  S
# 4783     4789               17.41  210100050104                  S
# ...       ...                 ...           ...                ...
# 1475     1481            39815.86  110300040708                  S
# 1938     1944            67619.22  131000000000                  S
# 1949     1955            37626.18  130402052007                  S
# 1469     1475            39468.25  110500021110                  S
# 1059     1060            37442.49  071000091212                  S
#
#      receivinghuc12                                     contained_hucs
# 4774   210100040600                                       210100040502  \
# 4789   210100050800                                       210100050301
# 4779   210100040600                                       210100040509
# 4775   210100040600                                       210100040503
# 4783   210100050800                                       210100050104
# ...             ...                                                ...
# 1475   110300100101  110200110902,110200120503,110200091008,1102001...
# 1938   130402011403                                       131000000000
# 1949   130402052404  130402051705,130402051112,130402051502,1304020...
# 1469   110500030203  110500010202,110500020107,110400010305,1105000...
# 1059   071100010601  071000050701,071000090607,071000090709,0710000...
#
#       num_contained_hucs                                    foreign_inflows
# 4774                   1                                                     \
# 4789                   1
# 4779                   1
# 4775                   1
# 4783                   1
# ...                  ...                                                ...
# 1475                 368                                       110200091001
# 1938                   1
# 1949                 362  130401000406,130401000408,130401000307,1304010...
# 1469                 386
# 1059                 425
#
#       num_foreign_inflows tophucid_bbox_container totophuc  bbox_area_sqkm
# 4774                    0                    4779  OUTSIDE       11.839246  \
# 4789                    0                    None  OUTSIDE       15.961644
# 4779                    0                    None  OUTSIDE       23.814385
# 4775                    0                    None  OUTSIDE       26.352014
# 4783                    0                    None  OUTSIDE       27.215604
# ...                   ...                     ...      ...             ...
# 1475                    1                    None     1483   126025.026268
# 1938                    0                    None     1955   142628.745971
# 1949                    7                    None     1959   146469.298861
# 1469                    0                    None     1476   152979.310277
# 1059                    0                    None     1064   167371.715091
#
#                                                geometry
# 4774  POLYGON ((-66.08714 17.96425, -66.08731 17.964...
# 4789  POLYGON ((-65.67754 18.36661, -65.67745 18.366...
# 4779  POLYGON ((-65.96558 17.97343, -65.96560 17.973...
# 4775  POLYGON ((-66.07535 17.96552, -66.07542 17.965...
# 4783  POLYGON ((-65.78897 18.11622, -65.78858 18.116...
# ...                                                 ...
# 1475  POLYGON ((-103.31611 37.28287, -103.31680 37.2...
# 1938  POLYGON ((-104.87690 29.92567, -104.87557 29.9...
# 1949  POLYGON ((-105.34992 30.57171, -105.35024 30.5...
# 1469  POLYGON ((-103.07970 36.73863, -103.08031 36.7...
# 1059  POLYGON ((-94.94874 41.92694, -94.94963 41.926...
#
# [4800 rows x 13 columns]
