# %%
import sys
sys.path.append('../..')
import geopandas as gpd

from src.pyagnps import topagnps

# %%
path_to_raster_dir = 'C:/Users/Luc/projects/pyagnps/inputs/TNM_DEM/HRNHDPlusRasters0708/'
path_to_write_dir = 'D:/AIMS/NHDPlusHR_raster_tests/'

# path_to_raster_dir = 'D:/AIMS/NHDPlusHR_raster_tests/hydrodem_clipped/'
# path_to_write_dir = 'D:/AIMS/NHDPlusHR_raster_tests/hydrodem_clipped/'

# %%
importlib.reload(topagnps);
# hydrodem, shift = topagnps.process_hydrodem_for_topagnps(path_to_raster_dir, path_to_write_dir=path_to_write_dir, wall_threshold_m=4000, unwall=False, unfill=False, applyshift=True)
# del hydrodem
hydrodem, shift = topagnps.process_hydrodem_for_topagnps(path_to_raster_dir, path_to_write_dir=path_to_write_dir, wall_threshold_m=4800, unwall=True, unfill=False, applyshift=True)
# del hydrodem
# hydrodem, shift = topagnps.process_hydrodem_for_topagnps(path_to_raster_dir, path_to_write_dir=path_to_write_dir, wall_threshold_m=4000, unwall=True, unfill=True, applyshift=True)
# Out:
# knocking down walls!
# applying shift
# writing to raster

# %%
hydrodem.plot()
